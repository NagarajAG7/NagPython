# %%
def even_odd():
    num1=eval(input("enter a number:"))
    if num1%2==0:
        print(f'{num1} is an Even')
    else:
        print(f'{num1} is an Odd')
even_odd()
# Out:
# enter a number: 101
# 101 is an Odd

# %%
def even_odd2(num2=202):
    global num2
    #num2=eval(input("enter a number:"))
    if num1%2==0:
        print(f'{num1} is an Even')
    else:
        print(f'{num1} is an Odd')
even_odd2()
# Out:
#   Cell In[3], line 2
#     global num2
#     ^
# SyntaxError: name 'num2' is parameter and global

# %%
def even_odd2():
    global num2
    num2=40    
    #num2=eval(input("enter a number:"))
    if num2%2==0:
        print(f'{num2} is an Even')
    else:
        print(f'{num2} is an Odd')
even_odd2()
# Out:
# 40 is an Even

# %% [markdown]
# **return**
#
# - return means function is giving something
#
# - we know that local variables cannot use outside the function

# %%
a,b=10,20
a,b=b,a
a,b
print(a,b)
# Out:
# 20 10

# %%
value=10,20
val1,val2=10,20       # works
#val1,val2=10         # fails

# %%
val1
# Out:
# 10

# %%
val2
# Out:
# 20

# %%
val1, val2
# Out:
# (10, 20)

# %%
def add():
    a=10
    b=20
    c=a+b
    return(c)
c=add()

# %%
c
# Out:
# 30

# %%
a
# Out:
# 20

# %%
b
# Out:
# 10

# %%
def add1():
    a1=10
    b1=20
    c1=a1+b1
    return(a1,c1)
a1,c1=add1()

# %%
a
# Out:
# 10

# %%
print(a1,c1)
# Out:
# 10 30

# %%
def avg(a2=100,b2=200,c2=300):
    summ=a2+b2+c2
    AVG=summ/3
    return(a2,c2,summ)
a2,c2,summ=avg()

# %%
a2
# Out:
# 100

# %%
Summ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 Summ
#
# NameError: name 'Summ' is not defined

# %%
def even_odd3():
    
    num3=eval(input("enter a number:"))
    if num3%2==0:
        print(f'{num3} is an Even')
    else:
        print(f'{num3} is an Odd')
    
    return(num3)
num3=even_odd3()
# Out:
# enter a number: 55
# 55 is an Odd

# %%
def even_odd4():  
    num4=eval(input("enter a number:"))
    if num4%2==0:
        print(f'{num4} is an Even')
        return(num4+10)        
    else:
        print(f'{num4} is an Odd')
        return(num4-10)
num4=even_odd4()
print(num4)
# Out:
# enter a number: 3
# 3 is an Odd
# -7

# %%
def even_odd5():  
    num4=eval(input("enter a number:"))
    if num4%2==0:
        #print(f'{num4} is an Even')
        return(num4+10)        
    else:
        #print(f'{num4} is an Odd')
        return(num4-10)
num4=even_odd5()
print(num4)
# Out:
# enter a number: 14
# 24

# %%
def even_odd6():  
    num4=eval(input("enter a number:"))
    if num4%2==0:
        print(f'{num4} is an Even')
        #return(num4+10)        
    else:
        print(f'{num4} is an Odd')
        #return(num4-10)
num4=even_odd6()
#print(num4)
# Out:
# enter a number: 6
# 6 is an Even

# %% [markdown]
# **function in function**

# %%
def greet1():
    print('Good Morn')

def greet2():
    print('Good Night')

greet1()
greet2()
# Out:
# Good Morn
# Good Night

# %% [markdown]
# **recursive error**

# %%
#**recursive error*
def greet11():
    print('Good Morn')
    greet22()

def greet22():
    print('Good Night')
    greet11()

greet11()
#greet22()
# Out:
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# Good Morn
# Good Night
# ...

# %%
#**recursive error*
def greet111():
    print('Good Morn')
    greet222()

def greet222():
    print('Good Night')
    #greet111()

greet111()
#greet222()
# Out:
# Good Morn
# Good Night

# %%
#**recursive error*
def greet111():
    print('Good Morn')
    #greet222()

def greet222():
    print('Good Night')
    greet111()

#greet111()
greet222()
# Out:
# Good Night
# Good Morn

# %%
#recursion error
def greet3():
    print('I dont know')
    greet3()

greet3()
# Out:
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# ...

# %%
#recursion error
def greet3():
    print('I dont know')
    greet3()

greet3()
# Out:
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# I dont know
# ...

# %%
def add(n):
    if n==0:
        return(0)
    else:
        return(n+add(n-1))

add(3)
# Out:
# 6

# %%
def factorial(n1):
   # n1=eval(input('Enter a value to find its factorial:'))
    if n1==0 or n1==1:
        return(1)
    else:
        return(n1*factorial(n1-1))

factorial(9)
# Out:
# 362880

# %%
def f1():
    n1=eval(input('Enter a value to find its factorial:'))
    if n1==0 or n1==1:
        return(1)
    else:
        return(n1*f1(n1-1))

f1()
# Out:
# Enter a value to find its factorial: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[279], line 8
#       5     else:
#       6         return(n1*f1(n1-1))
# ----> 8 f1()
#
# Cell In[279], line 6, in f1()
#       4     return(1)
#       5 else:
# ----> 6     return(n1*f1(n1-1))
#
# TypeError: f1() takes 0 positional arguments but 1 was given

# %%
def add(n):
    if n==0:
        return 0
    return(n+add(n-1))
add(5)
# Out:
# 15
